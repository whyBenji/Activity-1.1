# %% [raw]
# ---
# title : "PA_wrangle"
# author: Jatin Puri
# format:
#     html:
#         theme: cosmo
#         toc: true
#         code-fold: true
#         embed-resources: true
# ---

# %% [markdown]
# ## Intro
#
# In this PA, you will practice altering data frame objects in order to solve a riddle.
#
# ### Advice for troubleshooting your code
#
# #### Check results often
#
# If a chunk of code runs smoothly without giving you any error or warnings this does not necessarily mean it accomplished the desired task.
#
# It is a good habit to check the results of your code every time you finish a task.
#
# If you created or updated a data frame, make sure your edits did what you hoped.  Use the *Environment* or the `head()` function to investigate your changes.
#
# #### Document your work
#
# In the text before the code chunk, make sure to briefly state what the point of the chunk is.  This will remind later readers - which might be your future self! - what the desired output is.
#
# Use comments in the code to give quick explanations of the goals of complex steps.
#
# #### Two heads are better than one
#
# It can be hard to spot bugs in code that you yourself wrote.t
# (Have you ever sent a text message and not spotted an obvious  typo?  Same idea!)
#
# Work with people around you if you can - if something goes wrong, ask a friend to take a peek at your code and see if any glaring errors (like *syntax error*) pop out.
#
# #### Explain your code out loud
#
# The best way to troubleshoot a sneaky bug is to explain out loud each step of your code, and what you hoped to accomplish.
#
# If you are alone, try [Rubber Duck Debugging](https://en.wikipedia.org/wiki/Rubber_duck_debugging)!
#
# #### Google is your friend
#
# The whole of the internet is at your disposal!  Use it early, use it often.
#
# Copy-paste the exact error message into Google. Chances are, somebody else had a similar problem and got a similar message.
#
#
# Include package names in your search terms.  For example, "bar plot in plotnine with pandas data frame" is a better search than "bar plot in python".
#
#
# ## Part One: Data import and cleaning
#
# This section will walk you through some steps to clean up today's dataset, so that you can use it more easily in Part Two.
#
# First, we declare our package dependencies and load the data.
#
# (Note that the data loading function `read_csv` will give you an outpouring of helpful information about the dataset.  If you do not see the word "error", there is nothing to be concerned about.)

# %%
import numpy as np
import pandas as pd

colleges = pd.read_csv("https://www.dropbox.com/s/bt5hvctdevhbq6j/colleges.csv?dl=1")

# %%
colleges.head()
# Out:
#    Unnamed: 0                               INSTNM        CITY STABBR  \
# 0           1             Alabama A & M University      Normal     AL
# 1           2  University of Alabama at Birmingham  Birmingham     AL
# 2           3                   Amridge University  Montgomery     AL
# 3           4  University of Alabama in Huntsville  Huntsville     AL
# 4           5             Alabama State University  Montgomery     AL
#
#           ZIP  CONTROL  ADM_RATE  SAT_AVG  TUITIONFEE_IN  TUITIONFEE_OUT  ...  \
# 0       35762        1    0.9027    929.0         9857.0         18236.0  ...
# 1  35294-0110        1    0.9181   1195.0         8328.0         19032.0  ...
# 2  36117-3553        2       NaN      NaN         6900.0          6900.0  ...
# 3       35899        1    0.8123   1322.0        10280.0         21480.0  ...
# 4  36104-0271        1    0.9787    935.0        11068.0         19396.0  ...
#
#    LO_INC_COMP_2YR_TRANS_YR3_RT  NOLOAN_COMP_ORIG_YR4_RT  OPENADMP  \
# 0                           NaN                      NaN       2.0
# 1                           NaN                      NaN       2.0
# 2                           NaN                      NaN       1.0
# 3                           NaN                      NaN       2.0
# 4                           NaN                      NaN       2.0
#
#    PELL_COMP_4YR_TRANS_YR3_RT  DEATH_YR2_RT  NOLOAN_UNKN_ORIG_YR2_RT  \
# 0                         NaN           NaN                      NaN
# 1                         NaN           NaN                      NaN
# 2                         NaN           NaN                      NaN
# 3                         NaN           NaN                      NaN
# 4                         NaN           NaN                      NaN
#
#    NOT1STGEN_WDRAW_ORIG_YR6_RT  HI_INC_YR8_N  CUML_DEBT_P90  C100_L4
# 0                          NaN           NaN            NaN      NaN
# 1                          NaN           NaN            NaN      NaN
# 2                          NaN           NaN            NaN      NaN
# 3                          NaN           NaN            NaN      NaN
# 4                          NaN           NaN            NaN      NaN
#
# [5 rows x 27 columns]

# %%
colleges.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7058 entries, 0 to 7057
# Data columns (total 27 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Unnamed: 0                     7058 non-null   int64
#  1   INSTNM                         7058 non-null   object
#  2   CITY                           7058 non-null   object
#  3   STABBR                         7058 non-null   object
#  4   ZIP                            7058 non-null   object
#  5   CONTROL                        7058 non-null   int64
#  6   ADM_RATE                       2019 non-null   float64
#  7   SAT_AVG                        1315 non-null   float64
#  8   TUITIONFEE_IN                  4009 non-null   float64
#  9   TUITIONFEE_OUT                 3781 non-null   float64
#  10  UGDS                           6312 non-null   float64
#  11  REGION                         7058 non-null   int64
#  12  DEP_INC_PCT_H2                 0 non-null      float64
#  13  MD_INC_WDRAW_2YR_TRANS_YR4_RT  0 non-null      float64
#  14  IND_COMP_4YR_TRANS_YR4_RT      0 non-null      float64
#  15  SD_EARN_WNE_P10                0 non-null      float64
#  16  FEMALE_WDRAW_4YR_TRANS_YR6_RT  0 non-null      float64
#  17  LO_INC_COMP_2YR_TRANS_YR3_RT   0 non-null      float64
#  18  NOLOAN_COMP_ORIG_YR4_RT        0 non-null      float64
#  19  OPENADMP                       6149 non-null   float64
#  20  PELL_COMP_4YR_TRANS_YR3_RT     0 non-null      float64
#  21  DEATH_YR2_RT                   0 non-null      float64
#  22  NOLOAN_UNKN_ORIG_YR2_RT        0 non-null      float64
#  23  NOT1STGEN_WDRAW_ORIG_YR6_RT    0 non-null      float64
#  24  HI_INC_YR8_N                   0 non-null      float64
#  25  CUML_DEBT_P90                  0 non-null      float64
#  26  C100_L4                        3515 non-null   float64
# dtypes: float64(20), int64(3), object(4)
# memory usage: 1.5+ MB

# %% [markdown]
# The code chunks in this section will cause an error and/or do the desired task incorrectly.  (Even the chunks that run without error are not correct!) You will need to find the mistake, and correct it, to complete the intended action.
#
# None of the *text* is incorrect, only the *code* - your goal is to make the code do exactly what the documentation claims it will.
#
# #### 1. Narrow down the columns to variables of interest
#
# There are too many variables in this dataset.  We don't need all of them. We will limit our dataset down to only:
#
# Name of the institution
# City, State, and ZIP code of the institution
# The Admissions Rate
# The average SAT score
# The number of undergraduate students
# The in and out of state tuitions
# Whether the school is public or private
# The "REGION" variable.

# %%
colleges_clean = colleges[['INSTNM', 'CITY', 'STABBR', 'ZIP', 'CONTROL', 'ADM_RATE', 'SAT_AVG', 'TUITIONFEE_IN', 'TUITIONFEE_OUT', 'UGDS', 'REGION']]

# %%
colleges_clean
# Out:
#                                                  INSTNM              CITY  \
# 0                              Alabama A & M University            Normal
# 1                   University of Alabama at Birmingham        Birmingham
# 2                                    Amridge University        Montgomery
# 3                   University of Alabama in Huntsville        Huntsville
# 4                              Alabama State University        Montgomery
# ...                                                 ...               ...
# 7053                   Arizona State University at Yuma              Yuma
# 7054  Bay Area Medical Academy - San Jose Satellite ...          San Jose
# 7055                        High Desert Medical College         Lancaster
# 7056                                       BCI - Malden            Malden
# 7057          Health Career Institute- Lauderdale Lakes  Lauderdale Lakes
#
#      STABBR         ZIP  CONTROL  ADM_RATE  SAT_AVG  TUITIONFEE_IN  \
# 0        AL       35762        1    0.9027    929.0         9857.0
# 1        AL  35294-0110        1    0.9181   1195.0         8328.0
# 2        AL  36117-3553        2       NaN      NaN         6900.0
# 3        AL       35899        1    0.8123   1322.0        10280.0
# 4        AL  36104-0271        1    0.9787    935.0        11068.0
# ...     ...         ...      ...       ...      ...            ...
# 7053     AZ   853656900        1       NaN      NaN            NaN
# 7054     CA       95113        3       NaN      NaN            NaN
# 7055     CA   935340000        3       NaN      NaN            NaN
# 7056     MA    21480000        2       NaN      NaN            NaN
# 7057     FL   333137268        3       NaN      NaN        22575.0
#
#       TUITIONFEE_OUT     UGDS  REGION
# 0            18236.0   4824.0       5
# 1            19032.0  12866.0       5
# 2             6900.0    322.0       5
# 3            21480.0   6917.0       5
# 4            19396.0   4189.0       5
# ...              ...      ...     ...
# 7053             NaN      NaN       6
# 7054             NaN      NaN       8
# 7055             NaN      NaN       8
# 7056             NaN      NaN       1
# 7057             NaN      NaN       5
#
# [7058 rows x 11 columns]

# %% [markdown]
# #### 2. Remove observations that aren't needed
#
# Drop the schools that are "private for-profit" (category 3).  We will not need these for the puzzle.

# %%
colleges_clean = colleges_clean[colleges_clean['CONTROL'] != 3]

# %%
colleges_clean
# Out:
#                                                  INSTNM              CITY  \
# 0                              Alabama A & M University            Normal
# 1                   University of Alabama at Birmingham        Birmingham
# 2                                    Amridge University        Montgomery
# 3                   University of Alabama in Huntsville        Huntsville
# 4                              Alabama State University        Montgomery
# ...                                                 ...               ...
# 7050                 Arizona State University at Tucson            Tucson
# 7051  Arizona State University - ASU Colleges at Lak...  Lake Havasu City
# 7052        Arizona State University at The Gila Valley          Thatcher
# 7053                   Arizona State University at Yuma              Yuma
# 7056                                       BCI - Malden            Malden
#
#      STABBR         ZIP  CONTROL  ADM_RATE  SAT_AVG  TUITIONFEE_IN  \
# 0        AL       35762        1    0.9027    929.0         9857.0
# 1        AL  35294-0110        1    0.9181   1195.0         8328.0
# 2        AL  36117-3553        2       NaN      NaN         6900.0
# 3        AL       35899        1    0.8123   1322.0        10280.0
# 4        AL  36104-0271        1    0.9787    935.0        11068.0
# ...     ...         ...      ...       ...      ...            ...
# 7050     AZ   857454284        1       NaN      NaN            NaN
# 7051     AZ   864036877        1       NaN      NaN         6904.0
# 7052     AZ   855525545        1       NaN      NaN            NaN
# 7053     AZ   853656900        1       NaN      NaN            NaN
# 7056     MA    21480000        2       NaN      NaN            NaN
#
#       TUITIONFEE_OUT     UGDS  REGION
# 0            18236.0   4824.0       5
# 1            19032.0  12866.0       5
# 2             6900.0    322.0       5
# 3            21480.0   6917.0       5
# 4            19396.0   4189.0       5
# ...              ...      ...     ...
# 7050             NaN      NaN       6
# 7051         10106.0      NaN       6
# 7052             NaN      NaN       6
# 7053             NaN      NaN       6
# 7056             NaN      NaN       1
#
# [4089 rows x 11 columns]

# %% [markdown]
# ### 3. Adjust variable types: Numeric
#
# Some of the columns of the dataset were automatically understood by the computer to be categorical, due to missing data appearing like strings.
#
# Adjust the appropriate columns to be numeric.

# %%
colleges_clean['TUITIONFEE_IN'] = colleges['TUITIONFEE_IN']

colleges_clean['TUITIONFEE_OUT'] = colleges['TUITIONFEE_OUT']

colleges_clean['SAT_AVG'] = colleges['SAT_AVG']

colleges_clean['ADM_RATE'] = colleges['ADM_RATE']

# %% [markdown]
# ### 4. Adjust variable types: Categorical
#
# Similarly, columns of the dataset that are not numbers are automatically understood by the computer to be strings.
#
# We know, however, that some variables are truly *categorical*, in that there are only a few categories (or "levels") that can be values of the column.
#
# Adjust the appropriate columns to be understood as categorical.

# %%
colleges_clean['CONTROL'] = colleges_clean['CONTROL'].astype('str')
colleges_clean['REGION'] = colleges_clean['REGION'].astype('str')
# Out:
# /var/folders/nb/dnd338zx4qx6vlwx68gckp080000gn/T/ipykernel_1522/3841603596.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   colleges_clean['CONTROL'] = colleges_clean['CONTROL'].astype('str')
# /var/folders/nb/dnd338zx4qx6vlwx68gckp080000gn/T/ipykernel_1522/3841603596.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   colleges_clean['REGION'] = colleges_clean['REGION'].astype('str')

# %% [markdown]
# #### 5. Calculate new variables
#
# Create a new variable called TUITION_DIFF which contains the difference between in and out of state costs.

# %%
colleges_clean['TUITION_DIFF'] = colleges_clean['TUITIONFEE_OUT'] - colleges_clean['TUITIONFEE_IN']
# Out:
# /var/folders/nb/dnd338zx4qx6vlwx68gckp080000gn/T/ipykernel_1522/721408952.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   colleges_clean['TUITION_DIFF'] = colleges_clean['TUITIONFEE_OUT'] - colleges_clean['TUITIONFEE_IN']

# %%
colleges_clean
# Out:
#                                                  INSTNM              CITY  \
# 0                              Alabama A & M University            Normal
# 1                   University of Alabama at Birmingham        Birmingham
# 2                                    Amridge University        Montgomery
# 3                   University of Alabama in Huntsville        Huntsville
# 4                              Alabama State University        Montgomery
# ...                                                 ...               ...
# 7050                 Arizona State University at Tucson            Tucson
# 7051  Arizona State University - ASU Colleges at Lak...  Lake Havasu City
# 7052        Arizona State University at The Gila Valley          Thatcher
# 7053                   Arizona State University at Yuma              Yuma
# 7056                                       BCI - Malden            Malden
#
#      STABBR         ZIP  CONTROL  ADM_RATE  SAT_AVG  TUITIONFEE_IN  \
# 0        AL       35762        1    0.9027    929.0         9857.0
# 1        AL  35294-0110        1    0.9181   1195.0         8328.0
# 2        AL  36117-3553        2       NaN      NaN         6900.0
# 3        AL       35899        1    0.8123   1322.0        10280.0
# 4        AL  36104-0271        1    0.9787    935.0        11068.0
# ...     ...         ...      ...       ...      ...            ...
# 7050     AZ   857454284        1       NaN      NaN            NaN
# 7051     AZ   864036877        1       NaN      NaN         6904.0
# 7052     AZ   855525545        1       NaN      NaN            NaN
# 7053     AZ   853656900        1       NaN      NaN            NaN
# 7056     MA    21480000        2       NaN      NaN            NaN
#
#       TUITIONFEE_OUT     UGDS  REGION  TUITION_DIFF
# 0            18236.0   4824.0       5        8379.0
# 1            19032.0  12866.0       5       10704.0
# 2             6900.0    322.0       5           0.0
# 3            21480.0   6917.0       5       11200.0
# 4            19396.0   4189.0       5        8328.0
# ...              ...      ...     ...           ...
# 7050             NaN      NaN       6           NaN
# 7051         10106.0      NaN       6        3202.0
# 7052             NaN      NaN       6           NaN
# 7053             NaN      NaN       6           NaN
# 7056             NaN      NaN       1           NaN
#
# [4089 rows x 12 columns]

# %% [markdown]
# #### 6. Deal with missing data
#
# Drop all the rows with missing data.
#
# (It is often a terrible idea to simply drop all rows with *any* missing data!  Usually, even if *some* of the information is missing, we don't want to throw out the entire row.  In this example, however, we'll be lazy.)

# %%
colleges_clean = colleges_clean.dropna()

# %% [markdown]
# ## Part Two:  Identify the mystery college
#
# Wow!  Your best friend Ephelia has been accepted to the college of her dreams!  Unfortunately, Ephelia is a very mysterious person, and she won't tell you directly which college this is.  You'll have to use her clues to figure out which school is her dream school.
#
# Clues:
#
# 1. This college is located in Region 1.
#
# 2. This college's admission rate is in the first quartile for the region.
#
# 3. This college charges the same for in- and out-of-state tuition.
#
# 4. The average SAT score of this college is an odd number.
#
# 5. This college is NOT in New Hampshire or in the city of Boston.
#
# 6. More than 3,000 people apply to this college every year.  (Hint: Make a new variable to compute how many people apply.  Assume the size of an incoming class is 1/4 of the total undergraduate population, and remember that not everyone who *applies* is *admitted*.)
#
# 7. Ephelia is not going to an Ivy League school.
#
# 8. Of the two options remaining at this step, Ephelia will attend the cheaper one.

# %%
colleges_clean
# Out:
#                                    INSTNM              CITY STABBR  \
# 0                Alabama A & M University            Normal     AL
# 1     University of Alabama at Birmingham        Birmingham     AL
# 3     University of Alabama in Huntsville        Huntsville     AL
# 4                Alabama State University        Montgomery     AL
# 5               The University of Alabama        Tuscaloosa     AL
# ...                                   ...               ...    ...
# 6391                     Milligan College  Milligan College     TN
# 6401      Emory University-Oxford College            Oxford     GA
# 6424                    Husson University            Bangor     ME
# 6532    Piedmont International University     Winston-Salem     NC
# 6589          Purdue University Northwest           Hammond     IN
#
#              ZIP  CONTROL  ADM_RATE  SAT_AVG  TUITIONFEE_IN  TUITIONFEE_OUT  \
# 0          35762        1    0.9027    929.0         9857.0         18236.0
# 1     35294-0110        1    0.9181   1195.0         8328.0         19032.0
# 3          35899        1    0.8123   1322.0        10280.0         21480.0
# 4     36104-0271        1    0.9787    935.0        11068.0         19396.0
# 5     35487-0166        1    0.5330   1278.0        10780.0         28100.0
# ...          ...      ...       ...      ...            ...             ...
# 6391       37682        2    0.5776   1184.0        32500.0         32500.0
# 6401       30054        2    0.2894   1420.0        48502.0         48502.0
# 6424  04401-2929        2    0.8627   1048.0        17561.0         17561.0
# 6532       27101        2    0.3633    919.0         9480.0          9480.0
# 6589       46323        1    0.3467   1082.0         7582.0         17129.0
#
#          UGDS  REGION  TUITION_DIFF
# 0      4824.0       5        8379.0
# 1     12866.0       5       10704.0
# 3      6917.0       5       11200.0
# 4      4189.0       5        8328.0
# 5     32387.0       5       17320.0
# ...       ...     ...           ...
# 6391    806.0       5           0.0
# 6401    979.0       5           0.0
# 6424   2652.0       1           0.0
# 6532    336.0       5           0.0
# 6589   8665.0       3        9547.0
#
# [1310 rows x 12 columns]

# %%
colleges_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1310 entries, 0 to 6589
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   INSTNM          1310 non-null   object
#  1   CITY            1310 non-null   object
#  2   STABBR          1310 non-null   object
#  3   ZIP             1310 non-null   object
#  4   CONTROL         1310 non-null   object
#  5   ADM_RATE        1310 non-null   float64
#  6   SAT_AVG         1310 non-null   float64
#  7   TUITIONFEE_IN   1310 non-null   float64
#  8   TUITIONFEE_OUT  1310 non-null   float64
#  9   UGDS            1310 non-null   float64
#  10  REGION          1310 non-null   object
#  11  TUITION_DIFF    1310 non-null   float64
# dtypes: float64(6), object(6)
# memory usage: 133.0+ KB

# %%
df = colleges_clean
df1 = colleges_clean[colleges_clean['REGION']=="1"]
df1
# Out:
#                                          INSTNM           CITY STABBR  \
# 578                     Albertus Magnus College      New Haven     CT
# 584                    University of Bridgeport     Bridgeport     CT
# 585        Central Connecticut State University    New Britain     CT
# 590                   University of Connecticut         Storrs     CT
# 600                      University of Hartford  West Hartford     CT
# ...                                         ...            ...    ...
# 4764      University of Connecticut-Avery Point         Groton     CT
# 4765         University of Connecticut-Stamford       Stamford     CT
# 4915     Franklin W Olin College of Engineering        Needham     MA
# 5848  University of Connecticut-Hartford Campus       Hartford     CT
# 6424                          Husson University         Bangor     ME
#
#              ZIP CONTROL  ADM_RATE  SAT_AVG  TUITIONFEE_IN  TUITIONFEE_OUT  \
# 578   06511-1189       2    0.6388    930.0        31140.0         31140.0
# 584   06604-5620       2    0.5389    969.0        32250.0         32250.0
# 585         6050       1    0.6676   1071.0        10225.0         22914.0
# 590         6269       1    0.4784   1313.0        14880.0         36948.0
# 600   06117-1599       2    0.8089   1140.0        38910.0         38910.0
# ...          ...     ...       ...      ...            ...             ...
# 4764  06340-6097       1    0.9416   1111.0        12838.0         34906.0
# 4765  06901-2315       1    0.8232   1085.0        12848.0         34916.0
# 4915  02492-1200       2    0.1337   1522.0        51936.0         51936.0
# 5848        6103       1    0.9597   1101.0        12828.0         34896.0
# 6424  04401-2929       2    0.8627   1048.0        17561.0         17561.0
#
#          UGDS REGION  TUITION_DIFF
# 578    1122.0      1           0.0
# 584    3129.0      1           0.0
# 585    9317.0      1       12689.0
# 590   18930.0      1       22068.0
# 600    4835.0      1           0.0
# ...       ...    ...           ...
# 4764    619.0      1       22068.0
# 4765   1670.0      1       22068.0
# 4915    345.0      1           0.0
# 5848   1244.0      1       22068.0
# 6424   2652.0      1           0.0
#
# [89 rows x 12 columns]

# %% [markdown]
# ChaptGPT was used to understand how to find the first quartile.

# %%
q1 = colleges_clean['ADM_RATE'].quantile(0.25)
df2 =df1[colleges_clean['ADM_RATE']<=q1]
df2 = df2[df2['TUITION_DIFF']==0]
df2
# Out:
# /var/folders/nb/dnd338zx4qx6vlwx68gckp080000gn/T/ipykernel_1522/2361010562.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df2 =df1[colleges_clean['ADM_RATE']<=q1]
#                                       INSTNM           CITY STABBR  \
# 625                          Trinity College       Hartford     CT
# 630                          Yale University      New Haven     CT
# 1416                           Colby College     Waterville     ME
# 1500                         Amherst College        Amherst     MA
# 1505                          Babson College    Babson Park     MA
# 1512                      Bentley University        Waltham     MA
# 1518                          Boston College  Chestnut Hill     MA
# 1519                       Boston University         Boston     MA
# 1520                     Brandeis University        Waltham     MA
# 1537                         Emerson College         Boston     MA
# 1549                      Harvard University      Cambridge     MA
# 1567   Massachusetts Institute of Technology      Cambridge     MA
# 1577                   Mount Holyoke College   South Hadley     MA
# 1590                 Northeastern University         Boston     MA
# 1612                        Tufts University        Medford     MA
# 1613                       Wellesley College      Wellesley     MA
# 1617                         Wheaton College         Norton     MA
# 1619                        Williams College   Williamstown     MA
# 2027                       Dartmouth College        Hanover     NH
# 3175                        Brown University     Providence     RI
# 3180                      Providence College     Providence     RI
# 3184           Rhode Island School of Design     Providence     RI
# 3600                      Middlebury College     Middlebury     VT
# 4915  Franklin W Olin College of Engineering        Needham     MA
#
#              ZIP CONTROL  ADM_RATE  SAT_AVG  TUITIONFEE_IN  TUITIONFEE_OUT  \
# 625   06106-3100       2    0.3387   1370.0        54770.0         54770.0
# 630         6520       2    0.0693   1520.0        51400.0         51400.0
# 1416  04901-8840       2    0.1579   1444.0        53120.0         53120.0
# 1500  01002-5000       2    0.1290   1497.0        54310.0         54310.0
# 1505  02457-0310       2    0.2418   1347.0        49664.0         49664.0
# 1512  02452-4705       2    0.4415   1319.0        48000.0         48000.0
# 1518        2467       2    0.3241   1434.0        53346.0         53346.0
# 1519        2215       2    0.2511   1401.0        52082.0         52082.0
# 1520  02454-9110       2    0.3422   1403.0        53537.0         53537.0
# 1537  02116-4624       2    0.4606   1299.0        44832.0         44832.0
# 1549        2138       2    0.0516   1523.0        48949.0         48949.0
# 1567  02139-4307       2    0.0717   1532.0        49892.0         49892.0
# 1577  01075-1489       2    0.5084   1393.0        47940.0         47940.0
# 1590  02115-5005       2    0.2744   1482.0        49497.0         49497.0
# 1612  02155-5555       2    0.1491   1482.0        54318.0         54318.0
# 1613  02481-8203       2    0.2208   1448.0        51148.0         51148.0
# 1617  02766-2322       2    0.4789   1270.0        50850.0         50850.0
# 1619        1267       2    0.1458   1493.0        53550.0         53550.0
# 2027  03755-3529       2    0.1045   1483.0        53368.0         53368.0
# 3175        2912       2    0.0849   1494.0        53419.0         53419.0
# 3180  02918-0001       2    0.5152   1274.0        48764.0         48764.0
# 3184  02903-2784       2    0.3193   1276.0        48370.0         48370.0
# 3600        5753       2    0.1710   1446.0        52496.0         52496.0
# 4915  02492-1200       2    0.1337   1522.0        51936.0         51936.0
#
#          UGDS REGION  TUITION_DIFF
# 625    2174.0      1           0.0
# 630    5742.0      1           0.0
# 1416   1917.0      1           0.0
# 1500   1835.0      1           0.0
# 1505   2342.0      1           0.0
# 1512   4203.0      1           0.0
# 1518   9636.0      1           0.0
# 1519  16716.0      1           0.0
# 1520   3624.0      1           0.0
# 1537   3799.0      1           0.0
# 1549   7532.0      1           0.0
# 1567   4489.0      1           0.0
# 1577   2186.0      1           0.0
# 1590  13666.0      1           0.0
# 1612   5492.0      1           0.0
# 1613   2375.0      1           0.0
# 1617   1678.0      1           0.0
# 1619   2033.0      1           0.0
# 2027   4315.0      1           0.0
# 3175   6670.0      1           0.0
# 3180   4011.0      1           0.0
# 3184   1976.0      1           0.0
# 3600   2532.0      1           0.0
# 4915    345.0      1           0.0

# %% [markdown]
# Used chapGPT to understand how to use function on particular coloumn of the dataframe.

# %%
df3 = df2[df2['SAT_AVG'].apply(lambda x: x % 2 != 0)]
df3
# Out:
#                      INSTNM          CITY STABBR         ZIP CONTROL  \
# 1500        Amherst College       Amherst     MA  01002-5000       2
# 1505         Babson College   Babson Park     MA  02457-0310       2
# 1512     Bentley University       Waltham     MA  02452-4705       2
# 1519      Boston University        Boston     MA        2215       2
# 1520    Brandeis University       Waltham     MA  02454-9110       2
# 1537        Emerson College        Boston     MA  02116-4624       2
# 1549     Harvard University     Cambridge     MA        2138       2
# 1577  Mount Holyoke College  South Hadley     MA  01075-1489       2
# 1619       Williams College  Williamstown     MA        1267       2
# 2027      Dartmouth College       Hanover     NH  03755-3529       2
#
#       ADM_RATE  SAT_AVG  TUITIONFEE_IN  TUITIONFEE_OUT     UGDS REGION  \
# 1500    0.1290   1497.0        54310.0         54310.0   1835.0      1
# 1505    0.2418   1347.0        49664.0         49664.0   2342.0      1
# 1512    0.4415   1319.0        48000.0         48000.0   4203.0      1
# 1519    0.2511   1401.0        52082.0         52082.0  16716.0      1
# 1520    0.3422   1403.0        53537.0         53537.0   3624.0      1
# 1537    0.4606   1299.0        44832.0         44832.0   3799.0      1
# 1549    0.0516   1523.0        48949.0         48949.0   7532.0      1
# 1577    0.5084   1393.0        47940.0         47940.0   2186.0      1
# 1619    0.1458   1493.0        53550.0         53550.0   2033.0      1
# 2027    0.1045   1483.0        53368.0         53368.0   4315.0      1
#
#       TUITION_DIFF
# 1500           0.0
# 1505           0.0
# 1512           0.0
# 1519           0.0
# 1520           0.0
# 1537           0.0
# 1549           0.0
# 1577           0.0
# 1619           0.0
# 2027           0.0

# %%
df4 = df3[df3['CITY'] != 'Boston']
df4 = df4[df3['STABBR'] != 'NH']
df4
# Out:
#                      INSTNM          CITY STABBR         ZIP CONTROL  \
# 1500        Amherst College       Amherst     MA  01002-5000       2
# 1505         Babson College   Babson Park     MA  02457-0310       2
# 1512     Bentley University       Waltham     MA  02452-4705       2
# 1520    Brandeis University       Waltham     MA  02454-9110       2
# 1549     Harvard University     Cambridge     MA        2138       2
# 1577  Mount Holyoke College  South Hadley     MA  01075-1489       2
# 1619       Williams College  Williamstown     MA        1267       2
#
#       ADM_RATE  SAT_AVG  TUITIONFEE_IN  TUITIONFEE_OUT    UGDS REGION  \
# 1500    0.1290   1497.0        54310.0         54310.0  1835.0      1
# 1505    0.2418   1347.0        49664.0         49664.0  2342.0      1
# 1512    0.4415   1319.0        48000.0         48000.0  4203.0      1
# 1520    0.3422   1403.0        53537.0         53537.0  3624.0      1
# 1549    0.0516   1523.0        48949.0         48949.0  7532.0      1
# 1577    0.5084   1393.0        47940.0         47940.0  2186.0      1
# 1619    0.1458   1493.0        53550.0         53550.0  2033.0      1
#
#       TUITION_DIFF
# 1500           0.0
# 1505           0.0
# 1512           0.0
# 1520           0.0
# 1549           0.0
# 1577           0.0
# 1619           0.0

# %%
df4['Applicants'] = df4['UGDS']/(4*df4['ADM_RATE'])
df5 = df4[df4['Applicants']>3000]
df5
# Out:
#                   INSTNM          CITY STABBR         ZIP CONTROL  ADM_RATE  \
# 1500     Amherst College       Amherst     MA  01002-5000       2    0.1290
# 1549  Harvard University     Cambridge     MA        2138       2    0.0516
# 1619    Williams College  Williamstown     MA        1267       2    0.1458
#
#       SAT_AVG  TUITIONFEE_IN  TUITIONFEE_OUT    UGDS REGION  TUITION_DIFF  \
# 1500   1497.0        54310.0         54310.0  1835.0      1           0.0
# 1549   1523.0        48949.0         48949.0  7532.0      1           0.0
# 1619   1493.0        53550.0         53550.0  2033.0      1           0.0
#
#         Applicants
# 1500   3556.201550
# 1549  36492.248062
# 1619   3485.939643

# %%
# Answer is Williams College
